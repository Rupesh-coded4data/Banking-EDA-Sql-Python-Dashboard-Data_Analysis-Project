# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sqlalchemy import create_engine
connection_string ='mysql+pymysql://root:2103@localhost:3306/data_frame_db'
engine = create_engine(connection_string)

# %%
query= "Select * From banking_case.customer"

# %%
df = pd.read_sql(query, engine)

# %%
df.head(5)
# Out:
#   Client ID             Name  Age  Location ID Joined Bank   Banking Contact  \
# 0  IND81288    Raymond Mills   24        34324    5/6/2019    Anthony Torres
# 1  IND65833    Julia Spencer   23        42205  12/10/2001  Jonathan Hawkins
# 2  IND47499   Stephen Murray   27         7314   1/25/2010     Anthony Berry
# 3  IND72498   Virginia Garza   40        34594   3/28/2019        Steve Diaz
# 4  IND60181  Melissa Sanders   46        41269   7/20/2012        Shawn Long
#
#   Nationality            Occupation Fee Structure Loyalty Classification  ...  \
# 0    American  Safety Technician IV          High                   Jade  ...
# 1     African   Software Consultant          High                   Jade  ...
# 2    European    Help Desk Operator          High                   Gold  ...
# 3    American          Geologist II           Mid                 Silver  ...
# 4    American   Assistant Professor           Mid               Platinum  ...
#
# ...

# %%
df.shape
# Out:
# (3000, 28)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Client ID                 3000 non-null   object
#  1   Name                      3000 non-null   object
#  2   Age                       3000 non-null   int64
#  3   Location ID               3000 non-null   int64
#  4   Joined Bank               3000 non-null   object
#  5   Banking Contact           3000 non-null   object
#  6   Nationality               3000 non-null   object
#  7   Occupation                3000 non-null   object
#  8   Fee Structure             3000 non-null   object
#  9   Loyalty Classification    3000 non-null   object
#  10  Estimated Income          3000 non-null   float64
#  11  Superannuation Savings    3000 non-null   float64
#  12  Amount of Credit Cards    3000 non-null   int64
# ...

# %%
#Generate Descriptive Statitics for the DataFrame
df.describe()
# Out:
#                Age   Location ID  Estimated Income  Superannuation Savings  \
# count  3000.000000   3000.000000       3000.000000             3000.000000
# mean     51.039667  21563.323000     171305.034263            25531.599673
# std      19.854760  12462.273017     111935.808209            16259.950770
# min      17.000000     12.000000      15919.480000             1482.030000
# 25%      34.000000  10803.500000      82906.595000            12513.775000
# 50%      51.000000  21129.500000     142313.480000            22357.355000
# 75%      69.000000  32054.500000     242290.305000            35464.740000
# max      85.000000  43369.000000     522330.260000            75963.900000
#
#        Amount of Credit Cards  Credit Card Balance    Bank Loans  \
# count             3000.000000          3000.000000  3.000000e+03
# mean                 1.463667          3176.206943  5.913862e+05
# std                  0.676387          2497.094709  4.575570e+05
# ...

# %%
bins = [0,100000,300000, float('inf')]
labels = ['Low','Medium','High']

df['income Band'] = pd.cut(df['Estimated Income'], bins=bins, labels=labels, right=False)

# %%
df['income Band'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='income Band'>

# %%
#Examine the Distribution of Unique Catogories in Catogorical Columns
categorical_cols = df[["BRId","GenderId","IAId","Amount of Credit Cards","Nationality","Occupation",
                      "Fee Structure","Loyalty Classification","Properties Owned","Risk Weighting","income Band"]].columns

for col in categorical_cols:
    print(f"Value Counts for '{col}':")
    display(df[col].value_counts())
    print("\n" + "-"*50 + "\n")
# Out:
# Value Counts for 'BRId':
# BRId
# Private Bank     1352
# Retail            660
# Institutional     495
# Commercial        493
# Name: count, dtype: int64
# --------------------------------------------------
#
# Value Counts for 'GenderId':
# GenderId
# Female    1512
# Male      1488
# Name: count, dtype: int64
# --------------------------------------------------
#
# Value Counts for 'IAId':
# IAId
# Victor Dean          177
# Jeremy Porter        177
# Ernest Knight        177
# Eric Shaw            177
# Joe Carroll          177
# Steve Sanchez        176
# Daniel Carroll       176
# Victor Gutierrez     176
# Lawrence Sanchez     176
# Peter Castillo       176
# Carl Anderson        176
# Nicholas Ward        176
# Victor Rogers         89
# Kevin Kim             89
# Eugene Cunningham     89
# Fred Bryant           88
# Ryan Taylor           88
# Sean Vasquez          88
# Nicholas Morrison     88
# Jack Phillips         88
# Juan Ramirez          88
# Unknown               88
# ...

# %%
#Univariate Analysis

# %%
# Use a vibrant color palette for variety
palette = sns.color_palette("husl")  # Try "Set2", "pastel", or "deep" as alternatives

for i, predictor in enumerate(df[["BRId", "GenderId", "IAId", "Amount of Credit Cards", "Nationality", "Occupation",
                                  "Fee Structure", "Loyalty Classification", "Properties Owned", "Risk Weighting",
                                  "income Band"]].columns):
    plt.figure(figsize=(10, 6))
    sns.countplot(data=df, x=predictor, palette=palette)
    plt.title(f"Distribution of {predictor}", fontsize=14, fontweight='bold')
    plt.xlabel(predictor, fontsize=12)
    plt.ylabel("Count", fontsize=12)
    plt.xticks(rotation=45, fontsize=10)
    plt.yticks(fontsize=10)
    sns.despine()  # Clean style: removes top and right border
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\pace it\AppData\Local\Temp\ipykernel_5688\3884611694.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=predictor, palette=palette)
# C:\Users\pace it\AppData\Local\Temp\ipykernel_5688\3884611694.py:8: UserWarning: The palette list has more values (6) than needed (4), which may not be intended.
#   sns.countplot(data=df, x=predictor, palette=palette)
# C:\Users\pace it\AppData\Local\Temp\ipykernel_5688\3884611694.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x=predictor, palette=palette)
# ...

# %% [markdown]
# #Bivariate Analysis

# %%
palette = sns.color_palette("Set2")  # Try "husl", "pastel", or "deep" if you want variety
for i, predictor in enumerate(df[["BRId","GenderId","IAId","Amount of Credit Cards","Nationality","Occupation",
                                  "Fee Structure","Loyalty Classification","Properties Owned","Risk Weighting",
                                  "income Band"]].columns):
    plt.figure(figsize=(10, 6))
    sns.countplot(data=df, x=predictor, hue='GenderId', palette=palette)
    plt.title(f"Count of {predictor} by Gender", fontsize=14)
    plt.xlabel(predictor, fontsize=12)
    plt.ylabel("Count", fontsize=12)
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\pace it\AppData\Local\Temp\ipykernel_5688\401328842.py:6: UserWarning: The palette list has more values (8) than needed (2), which may not be intended.
#   sns.countplot(data=df, x=predictor, hue='GenderId', palette=palette)
# C:\Users\pace it\AppData\Local\Temp\ipykernel_5688\401328842.py:6: UserWarning: The palette list has more values (8) than needed (2), which may not be intended.
#   sns.countplot(data=df, x=predictor, hue='GenderId', palette=palette)
# C:\Users\pace it\AppData\Local\Temp\ipykernel_5688\401328842.py:6: UserWarning: The palette list has more values (8) than needed (2), which may not be intended.
#   sns.countplot(data=df, x=predictor, hue='GenderId', palette=palette)
# C:\Users\pace it\AppData\Local\Temp\ipykernel_5688\401328842.py:6: UserWarning: The palette list has more values (8) than needed (2), which may not be intended.
#   sns.countplot(data=df, x=predictor, hue='GenderId', palette=palette)
# ...

# %%
#Histplot of Values Counts for Different Occupation

# Set a clean style
sns.set_style('whitegrid')

for col in categorical_cols:
    if col == "Occupation":
        continue
    plt.figure(figsize=(8, 4))
    
    # Use a colorful palette
    color = sns.color_palette("Set2", len(df[col].unique()))[0]
    sns.histplot(df[col], color=color)
    
    # Use the actual column name in the title
    plt.title(f"Histogram of {col} Count", fontsize=14, fontweight='bold', color='darkblue')
    plt.xlabel(col, fontsize=12, color='darkgreen')
    plt.ylabel("Count", fontsize=12, color='darkred')
    
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.show()

# %% [markdown]
# #-----------------Numerical Analysis-----------------#

# %%
numerical_cols = [
    'Estimated Income', 'Superannuation Savings', 'Credit Card Balance',
    'Bank Loans', 'Checking Accounts', 'Saving Accounts',
    'Foreign Currency Account', 'Business Lending'
]

# Set Seaborn theme
sns.set_style("whitegrid")

# Create 8 subplots (one for each column)
fig, axes = plt.subplots(nrows=8, ncols=1, figsize=(10, 24))  # Adjusted height

# Define 8 different colors
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728',
          '#9467bd', '#8c564b', '#e377c2', '#7f7f7f']

# Plot each numerical column
for i, col in enumerate(numerical_cols):
    sns.histplot(data=df, x=col, kde=True, ax=axes[i], color=colors[i])
    axes[i].set_title(f"Distribution of {col}", fontsize=14)
    axes[i].set_xlabel(col)
    axes[i].set_ylabel("Count")

plt.tight_layout()
plt.show()

# %%
numerical_cols = [
    'Estimated Income', 'Superannuation Savings', 'Credit Card Balance',
    'Bank Loans', 'Checking Accounts', 'Saving Accounts',
    'Foreign Currency Account', 'Business Lending'
]

correlation_matrix = df[numerical_cols].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(
    correlation_matrix,
    annot=True,
    cmap='coolwarm',
    fmt=".2f",
    square=True,
    cbar_kws={'shrink': 0.8}
)
plt.title("Correlation Heatmap", fontsize=16)
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [raw]
#  Insights of EDA
#
# 1. The Strongest positive correlation occur among "Bank Deposits" with "Checking Accounts"."Saving Account" and "Foreign Currency
#    Account" indicating that Customers who maintain high balances in one account type often hold substaintail amount/funds accross
#    other accounts as well
